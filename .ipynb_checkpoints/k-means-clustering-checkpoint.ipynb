# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from numpy import arange

import sklearn
from sklearn.cluster import KMeans
from mpl_toolkits.mplot3d import Axes3D

import sklearn.metrics as sm
from sklearn.decomposition import PCA
from sklearn import datasets
from sklearn.metrics import confusion_matrix, classification_report

# %%
#Focusing on 100 choices from 200 subjects as a first step
choice_100 = pd.read_csv('IGTdataSteingroever2014\choice_100.csv')
choice_100 = choice_100[:200]

# %%
#All data types are the same and the original matrix is clean
choice_100.dtypes
# Out:
# Choice_1      int64
# Choice_2      int64
# Choice_3      int64
# Choice_4      int64
# Choice_5      int64
#               ...
# Choice_96     int64
# Choice_97     int64
# Choice_98     int64
# Choice_99     int64
# Choice_100    int64
# Length: 100, dtype: object

# %%
cluster = KMeans(n_clusters = 5)
cols = choice_100.columns[:]
cols
# Out:
# Index(['Choice_1', 'Choice_2', 'Choice_3', 'Choice_4', 'Choice_5', 'Choice_6',
#        'Choice_7', 'Choice_8', 'Choice_9', 'Choice_10', 'Choice_11',
#        'Choice_12', 'Choice_13', 'Choice_14', 'Choice_15', 'Choice_16',
#        'Choice_17', 'Choice_18', 'Choice_19', 'Choice_20', 'Choice_21',
#        'Choice_22', 'Choice_23', 'Choice_24', 'Choice_25', 'Choice_26',
#        'Choice_27', 'Choice_28', 'Choice_29', 'Choice_30', 'Choice_31',
#        'Choice_32', 'Choice_33', 'Choice_34', 'Choice_35', 'Choice_36',
#        'Choice_37', 'Choice_38', 'Choice_39', 'Choice_40', 'Choice_41',
#        'Choice_42', 'Choice_43', 'Choice_44', 'Choice_45', 'Choice_46',
#        'Choice_47', 'Choice_48', 'Choice_49', 'Choice_50', 'Choice_51',
#        'Choice_52', 'Choice_53', 'Choice_54', 'Choice_55', 'Choice_56',
#        'Choice_57', 'Choice_58', 'Choice_59', 'Choice_60', 'Choice_61',
#        'Choice_62', 'Choice_63', 'Choice_64', 'Choice_65', 'Choice_66',
#        'Choice_67', 'Choice_68', 'Choice_69', 'Choice_70', 'Choice_71',
#        'Choice_72', 'Choice_73', 'Choice_74', 'Choice_75', 'Choice_76',
#        'Choice_77', 'Choice_78', 'Choice_79', 'Choice_80', 'Choice_81',
#        'Choice_82', 'Choice_83', 'Choice_84', 'Choice_85', 'Choice_86',
#        'Choice_87', 'Choice_88', 'Choice_89', 'Choice_90', 'Choice_91',
#        'Choice_92', 'Choice_93', 'Choice_94', 'Choice_95', 'Choice_96',
#        'Choice_97', 'Choice_98', 'Choice_99', 'Choice_100'],
#       dtype='object')

# %%
choice_100["cluster"] = cluster.fit_predict(choice_100[choice_100.columns[1:]])
choice_100.head()
choice_100.tail()
# Out:
#           Choice_1  Choice_2  Choice_3  Choice_4  Choice_5  Choice_6  \
# Subj_196         4         2         3         1         4         2
# Subj_197         3         3         3         2         2         2
# Subj_198         1         1         1         1         1         1
# Subj_199         2         2         2         2         2         2
# Subj_200         1         1         1         2         2         2
#
#           Choice_7  Choice_8  Choice_9  Choice_10  ...  Choice_92  Choice_93  \
# Subj_196         3         1         4          2  ...          1          3
# Subj_197         2         2         4          4  ...          4          2
# Subj_198         1         2         2          2  ...          4          4
# Subj_199         2         2         2          1  ...          4          1
# Subj_200         2         2         2          2  ...          4          4
#
#           Choice_94  Choice_95  Choice_96  Choice_97  Choice_98  Choice_99  \
# Subj_196          3          3          3          3          3          3
# Subj_197          2          2          2          2          2          2
# Subj_198          4          4          4          4          4          4
# Subj_199          3          3          3          3          3          3
# Subj_200          4          4          4          4          4          4
#
#           Choice_100  cluster
# Subj_196           3        1
# Subj_197           2        1
# Subj_198           4        1
# Subj_199           3        0
# Subj_200           4        2
#
# [5 rows x 101 columns]

# %%
pca = PCA(n_components = 2)
choice_100["x"] = pca.fit_transform(choice_100[cols])[:,0]
choice_100["y"] = pca.fit_transform(choice_100[cols])[:,1]
choice_100 = choice_100.reset_index()
choice_100.tail()
# Out:
#         index  Choice_1  Choice_2  Choice_3  Choice_4  Choice_5  Choice_6  \
# 195  Subj_196         4         2         3         1         4         2
# 196  Subj_197         3         3         3         2         2         2
# 197  Subj_198         1         1         1         1         1         1
# 198  Subj_199         2         2         2         2         2         2
# 199  Subj_200         1         1         1         2         2         2
#
#      Choice_7  Choice_8  Choice_9  ...  Choice_94  Choice_95  Choice_96  \
# 195         3         1         4  ...          3          3          3
# 196         2         2         4  ...          2          2          2
# 197         1         2         2  ...          4          4          4
# 198         2         2         2  ...          3          3          3
# 199         2         2         2  ...          4          4          4
#
#      Choice_97  Choice_98  Choice_99  Choice_100  cluster         x         y
# 195          3          3          3           3        1  1.105869  1.234054
# 196          2          2          2           2        1 -1.154505  1.662163
# 197          4          4          4           4        1  3.482359  7.287164
# 198          3          3          3           3        0 -5.739960 -1.209768
# 199          4          4          4           4        2  6.347627 -0.082115
#
# [5 rows x 104 columns]

# %%
df = choice_100[["index", "cluster", "x", "y"]]
df.columns = ["Subjects", "Cluster", "X", "Y"]
df.head()
# Out:
#   Subjects  Cluster         X         Y
# 0   Subj_1        0 -2.911773 -1.124068
# 1   Subj_2        4  0.371965  1.531962
# 2   Subj_3        0 -3.021308 -0.008141
# 3   Subj_4        3  1.220158 -1.627644
# 4   Subj_5        3  0.067286 -0.325107

# %%
import seaborn as sns
sns.scatterplot(data=df,x="X", y="Y", hue="Cluster")
# Out:
# <AxesSubplot:xlabel='X', ylabel='Y'>

# %%
#Now that we have looked at the different choices that have been made we can take a look at the results
win_100 = pd.read_csv('IGTdataSteingroever2014\wi_100.csv')
loss_100 = pd.read_csv("IGTdataSteingroever2014\lo_100.csv")

# %%
win_100.tail(5)
# Out:
#         Wins_1  Wins_2  Wins_3  Wins_4  Wins_5  Wins_6  Wins_7  Wins_8  \
# Subj_1     100     100     100      50      50     100     100     100
# Subj_2     100     100      50      50      50     100      50     100
# Subj_3      50     100      50     100      50     100      50      50
# Subj_4      50      50      50     100     100      50      50     100
# Subj_5     100     100     100     100     100      50      50     100
#
#         Wins_9  Wins_10  ...  Wins_91  Wins_92  Wins_93  Wins_94  Wins_95  \
# Subj_1      50      100  ...      100      100      100      100      100
# Subj_2     100      100  ...       50      100       50       50      100
# Subj_3      50       50  ...       50      100      100       50      100
# Subj_4     100      100  ...       50      100       50       50       50
# Subj_5      50      100  ...      100      100      100      100       50
#
#         Wins_96  Wins_97  Wins_98  Wins_99  Wins_100
# Subj_1      100       50      100       50       100
# Subj_2       50       50      100      100        50
# Subj_3      100      100       50      100       100
# Subj_4       50      100       50       50        50
# Subj_5       50       50       50       50        50
#
# [5 rows x 100 columns]

# %%
loss_100.tail(5)
# Out:
#         Losses_1  Losses_2  Losses_3  Losses_4  Losses_5  Losses_6  Losses_7  \
# Subj_1      -200      -150         0      -250         0         0         0
# Subj_2         0         0         0         0         0         0       -50
# Subj_3         0         0       -50      -300         0     -1250         0
# Subj_4      -250       -50         0         0      -200         0         0
# Subj_5         0         0         0     -1250         0       -50         0
#
#         Losses_8  Losses_9  Losses_10  ...  Losses_91  Losses_92  Losses_93  \
# Subj_1         0         0          0  ...          0          0       -350
# Subj_2         0         0          0  ...          0          0          0
# Subj_3         0         0        -50  ...        -50          0       -200
# Subj_4         0         0      -1250  ...          0          0          0
# Subj_5         0         0          0  ...          0          0          0
#
#         Losses_94  Losses_95  Losses_96  Losses_97  Losses_98  Losses_99  \
# Subj_1          0          0          0          0          0          0
# Subj_2       -250      -1250          0          0          0          0
# Subj_3          0          0          0          0          0          0
# Subj_4          0        -50          0          0          0        -50
# Subj_5      -1250          0          0          0        -50          0
#
#         Losses_100
# Subj_1       -1250
# Subj_2           0
# Subj_3           0
# Subj_4           0
# Subj_5           0
#
# [5 rows x 100 columns]

# %%
choice_100.tail(5)
